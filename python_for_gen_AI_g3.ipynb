# %% [markdown]
# <a href="https://colab.research.google.com/github/gopinathsau15-sudo/Shoolini-Project/blob/main/python_for_gen_AI_g3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 x=10
x
mysub="python"
mysub
# Out:
# 'python'

# %%
print(mysub)
# Out:
# python

# %%
mycity="tamluk"
mycity
# Out:
# 'tamluk'

# %%
mysub1="generative AI"
mysub1
# Out:
# 'generative AI'

# %%
#for variable nameing we cannot use space,symbole and keyword
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#data type in python
#numeric
#1 integer--- adsence of decimal point is known integer
#ex-- 1,2,3,4,5
x=1
type(x)
# Out:
# int

# %%
#floating point number -- presence of decimal point
#ex --2.13,4.35
y=0.0
type(y)
# Out:
# float

# %%
#complex -- combination of real and imaginary
z=3+4j
type(z)
# Out:
# complex

# %%
#string-- data in the from text
x="tamluk"
type(x)
# Out:
# str

# %%
#booleam-- it used to store valuse true and false
a=True
type(a)
# Out:
# bool

# %%
b=False
type(b)
# Out:
# bool

# %%
#none--- define null value
e=None
type(e)
# Out:
# NoneType

# %%
#single quotes sting
mysub='GEN AI'
type(mysub)
# Out:
# str

# %%
#doble quotes string
mycollege="sholini university"
type(mycollege)
# Out:
# str

# %%
#tripel quotes string
mysentence='''this is miltiple line sentence,
it is also known as string'''
type(mysentence)
# Out:
# str

# %%
mysub="machine learning"
print(mysub)
# Out:
# machine learning

# %%
len(mysub)#len()is function which is lenth of string
# Out:
# 16

# %%
mysub[2]
# Out:
# 'c'

# %%
mysub[-1]
# Out:
# 'g'

# %%
mysub[-16]
# Out:
# 'm'

# %%
mysub="maching learing"
mysub[0:10:1]
# Out:
# 'maching le'

# %%
mysub[3:7:1]
# Out:
# 'hing'

# %%
#lower()---this method convert string into case
my_sub ="PYTHON"
my_sub.lower()
# Out:
# 'python'

# %%
#upper ()-- this method convert string into upper case
my_sub = " Machine learing"
my_sub.upper()
# Out:
# ' MACHINE LEARING'

# %%
#count()---this method count perticular character in string
my_sub = " Machine learing"
my_sub.count('a')
# Out:
# 2

# %%
#list
my_list = [89,76,54,23,25]#homogenius list
type(my_list)
# Out:
# list

# %%
print(my_list)
# Out:
# [89, 76, 54, 23, 25]

# %%
mixed_list = [76,2.45,"apple",True,None]#hetrogenous list
type(mixed_list)
# Out:
# list

# %%
#positive indexing
my_list = [78,54,32,89,23]
print(my_list[0])
print(my_list[1])
print(my_list[2])
# Out:
# 78
# 54
# 32

# %%
#negative indexing
my_list = [78,54,32,89,23]
print(my_list[0])
print(my_list[-1])
print(my_list[-2])
# Out:
# 78
# 23
# 89

# %%
#slicing
my_list = [78,54,32,89,23]
my_list[0:4:1]
# Out:
# [78, 54, 32, 89]

# %%
my_list[:4]
# Out:
# [78, 54, 32, 89]

# %%
my_list[: :-1]
# Out:
# [23, 89, 32, 54, 78]

# %%
#funtion in list
print(my_list)
# Out:
# [78, 54, 32, 89, 23]

# %%
min (my_list)
# Out:
# 23

# %%
max(my_list)
# Out:
# 89

# %%
sum(my_list)
# Out:
# 276

# %%
#sorted()--this function arrange list increseing ordeer and decresing
sorted(my_list)
# Out:
# [23, 32, 54, 78, 89]

# %%
#sorted()--this function arrange list increseing ordeer and decresing
sorted(my_list, reverse=True)
# Out:
# [89, 78, 54, 32, 23]

# %%
# list function is not chamge orginal list
print(my_list)
# Out:
# [78, 54, 32, 89, 23]

# %%
#append()--- this methord add item end of the list
my_list.append(100)
print(my_list)
# Out:
# [78, 54, 32, 89, 23, 100]

# %%
#extend()--this methord marge list into another list
list1 = [89,90,67]
list2 = [23,45,67]
list1.extend(list2)
print(list1)
# Out:
# [89, 90, 67, 23, 45, 67]

# %%
from os import truncate
#short()-- this method use to arange list into incresing or deresing order
my_list = [12,23,9,8,78]
my_list.sort(reverse=True)
my_list
# Out:
# [78, 23, 12, 9, 8]

# %%
#pop()--this method remove item from the list and take index as arument
list1 = [12,23,45,13]
list1.pop(2)
# Out:
# 45

# %%
#remoove()--this method remove item from the list as argument
my_list = [89,67,54,34]
my_list.remove(67)

# %%
my_list
# Out:
# [89, 54, 34]

# %%
my_dict = {"name" :"aman", "college" :"shoolini" }
print(my_dict)
# Out:
# {'name': 'aman', 'college': 'shoolini'}

# %%
#key()----this metod return keys of dictionary
list(my_dict.keys())
# Out:
# ['name', 'college']

# %%
#values()---this method find value of the dictionary
list(my_dict.values())
# Out:
# ['aman', 'shoolini']

# %%
#ithems()--this method return item of the dictionnary
list(my_dict.items())
# Out:
# [('name', 'aman'), ('college', 'shoolini')]

# %%
#get()
my_dict.get("name")
# Out:
# 'aman'

# %%
#update()-- this method update dictionary and take  dictionary as argu
my_dict.update({"age": 20})
print(my_dict)
# Out:
# {'name': 'aman', 'college': 'shoolini', 'age': 20}

# %%
my_sub ="python"
print(my_sub[0])
print(my_sub[1])
print(my_sub[2])
# Out:
# p
# y
# t

# %%
my_sub = "python"
for i in my_sub:
  print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for i in range(0,6,1):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(6):
  print(1)
# Out:
# 1
# 1
# 1
# 1
# 1
# 1

# %%
def add():
  a = int(input("enter first number: "))
  b = int(input("enter second number: "))
  return a+b

# %%
print(add())
# Out:
# enter first number: 45\
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3168568086.py in <cell line: 0>()
# ----> 1 print(add())
#
# /tmp/ipython-input-1349630181.py in add()
#       1 def add():
# ----> 2   a = int(input("enter first number: "))
#       3   b = int(input("enter second number: "))
#       4   return a+b
#
# ValueError: invalid literal for int() with base 10: '45\\'

# %%
def Calculation(a,b):
  print("addition",a+b)
  print("subtraction",a-b)
  print("multiplication",a*b)
  print("divition",a/b)
  return "calculation is complete"

# %%
print(Calculation(10,5))

# %%
def area_perimeter(width = 4, hight = 8):
  area = width*hight
  perimter = 2*(width+hight)
  return "area is", area, "and perimeter is",perimter

# %%
print(area_perimeter(10,20))

# %%
import numpy as np

# %%
#one dimensional array
oned_arry = np.array([1,2,3,4])
print(oned_arry)

# %%
#two dimensional array
twod_array = np.array([[1,2,3,4],[4,5,6,7]])
print(twod_array)
# Out:
# [[1 2 3 4]
#  [4 5 6 7]]

# %%
print(twod_array.ndim)
# Out:
# 2

# %%
#size--represents the number of items in the array
print(twod_array.size)
# Out:
# 8

# %%
#shape ---shape of the array
print(twod_array.shape)
# Out:
# (2, 4)

# %%
#indexing
print(twod_array[0])
# Out:
# [1 2 3 4]

# %%
print(twod_array[1][2])
# Out:
# 6

# %%
print(twod_array[0:2,0:2])

# %%
row_vector = np.array([{1,2,3}])
print(row_vector)
# Out:
# [{1, 2, 3}]

# %%
column_vector = np.array([[1],[2],[3]])
print(column_vector)
# Out:
# [[1]
#  [2]
#  [3]]

# %%
mat1 = np.matrix("1,2,3,4;5,6,7,8")
print(mat1)

# %%
zeros_array = np.zeros((3,3),dtype=int)
print(zeros_array)
# Out:
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]

# %%
ones_array = np.ones((3,3),dtype=int)
print(ones_array)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#line plot
xpoint = np.array([1,3])
ypoint = np.array([2,4])
plt.plot(xpoint,ypoint)
plt.show()

# %%
cgpa = np.array([6,6.5,7,7.8,8.6,9,9.2,9.5,6.9,10])
package = np.array([4,4.5,5,5.8,6.2,6.8,7,7.5,8,8.5])
plt.plot(cgpa,package, "*:g", ms = 20,)
font1 = {'family':'serif','color' :'red','size':15}
font2 = {'family':'serif','color':'blue','size':20}



plt.xlabel("cgpa",fontdict = font2)
plt.ylabel("package",fontdict = font1)
plt.title("cgpa vs package" ,fontdict = font2)
plt.show()

# %%
fruit=np.array(["apple","banana","mango","orange"])
quantity = np.array([10,20,40,50])
color = np.array(["red","yellow","black","pink"])
plt.bar(fruit,quantity, color = color)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
fruit = np.array(["apple","banana","orange"])
quantity = np.array([100,120,150])
plt.barh(fruit,quantity)
plt.show()

# %%
fruit = np.array(["apple","banana","orange","watermelon"])
percentage_of_fruit = np.array([25,20,25,30])
plt.pie(percentage_of_fruit,labels = fruit)
plt.show()

# %%
age_of_car = np.array([4,5,6,7,8])
speed_of_car = np.array([150,140,130,120,110])
plt.scatter(age_of_car,speed_of_car)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2066190360.py in <cell line: 0>()
#       1 age_of_car = np.array([4,5,6,7,8])
#       2 speed_of_car = np.array([150,140,130,120,110])
# ----> 3 plt.scatter(age_of_car,speed_of_car)
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
x = np.random.randint(40,100,(1,200))
x = x.flatten()
plt.hist(x)
plt.hist(x,bins = 20)
# Out:
# (array([10., 10.,  6., 13.,  8., 11.,  7.,  9., 10.,  9.,  7., 11., 14.,
#         12., 14.,  6., 11.,  8.,  9., 15.]),
#  array([40. , 42.9, 45.8, 48.7, 51.6, 54.5, 57.4, 60.3, 63.2, 66.1, 69. ,
#         71.9, 74.8, 77.7, 80.6, 83.5, 86.4, 89.3, 92.2, 95.1, 98. ]),
#  <BarContainer object of 20 artists>)

# %%
#pandas --IT IS PYTHON LIBRARY
#1.series -1d
#2.datafrem -2d
#3.panel - 3d

# %%
#how to import pandas
   #import pandas as pd

# %%
import pandas as pd

# %%
fruit_list = ["apple","banana","orange","watermelon"]
my_series = pd.Series(fruit_list,name = "fruit")
print(my_series)
# Out:
# 0         apple
# 1        banana
# 2        orange
# 3    watermelon
# Name: fruit, dtype: object

# %%
list_of_list = [["apple",100],["banana",200],["orange",150],["watermelon",80]]
my_df = pd.DataFrame(list_of_list,columns = ["fruit","quantity"])
print(my_df)
# Out:
#         fruit  quantity
# 0       apple       100
# 1      banana       200
# 2      orange       150
# 3  watermelon        80

# %%
df = pd.read_csv

# %%
import numpy as np
import matplotlib.pyplot as plt
cgpa = np.array([4,5,6,7,8])
package = np.array([7,8,9,5,6])
plt.plot(cgpa,package,"*:g",ms = 30)
plt.xlabel("cgpa")
plt.ylabel("package")
plt.title("cgpa vs package")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
import matplotlib.pyplot as plt
fruit = np.array(["apple","banana","orange","watermelon"])
quantity = np.array([100,200,300,50])
color = np.array(["red","blue","green","yellow"])
plt.bar(fruit,quantity,color=color)
plt.show()

# %%
fruit=np.array(["apple","banana","mango","orange"])
quantity = np.array([10,20,40,50])
color = np.array(["red","yellow","black","pink"])
plt.bar(fruit,quantity, color = color)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
fruit=np.array(["apple","banana","mango","orange"])
quantity = np.array([10,20,40,50])
color = np.array(["red","yellow","black","pink"])
plt.barh(fruit,quantity, color = color)
plt.show()

# %%
import pandas as pd

# %%
import pandas as pd
fruit_list = ["apple","banana","orange","watermelon"]
my_series = pd.Series(fruit_list,name="fruit")
print(my_series)
# Out:
# 0         apple
# 1        banana
# 2        orange
# 3    watermelon
# Name: fruit, dtype: object

# %%
list_of_list =["apple",100],["banana"200,]
my_df = pd.DataFrame(list_of_list,columns = ["fruit","quantity"])

# %%
import numpy as np
from numpy.linalg import norm
A = np.array([2,1,2,3,2,9])
B = np.array([3,4,2,4,5,5])
cosine = np.dot(A,B)/(norm(A)*norm(B))
print("cosine similarity:", cosine)
# Out:
# cosine similarity: 0.8188504723485274

# %%
from transformers import pipeline
summarizer = pipeline("summarization",model="facebook/bart-large-cnn")
text = """" The global shift toward renewable energy is accelerating
driven by concern over climate change and energy security."""
summary = summarizer(text,max_length=30,min_length=10,do_sample=False)
print(summary[0])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# ...
